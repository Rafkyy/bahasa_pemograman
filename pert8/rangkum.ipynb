# %% [markdown]
# 1. Definition
# Arrays (in python) are structures that can store and organize data sets. Data structures talk about a way to store, organize, group and represent data. Data structures are very important and must be mastered by a programmer. On programming forums, I often come across questions that I think can be solved if the person understands the concept of data structures. In this material, we will discuss advanced data structures, namely sets and dictionaries.
# 2. Set
# A set in the python programming language is a collective data type that is used to store multiple values in a single variable with the following
# conditions:
# • stored member values must be unique (not duplicates)
# • The value of the member that has been entered cannot be changed anymore
# • set is unordered aka unordered-which means it can't be accessed by index.
# To better understand the 3 points above, we will immediately do the practice.

# %% [markdown]
# 1. Definisi
# Array (dalam python) adalah struktur yang dapat menyimpan dan mengatur kumpulan data. Struktur data berbicara tentang cara menyimpan, mengatur, mengelompokkan, dan merepresentasikan data. Struktur data sangatlah penting dan harus dikuasai oleh seorang programmer. Di forum-forum pemrograman, saya sering menjumpai pertanyaan-pertanyaan yang menurut saya bisa diselesaikan jika orang tersebut memahami konsep struktur data. Pada materi kali ini kita akan membahas tentang struktur data lanjutan yaitu himpunan dan kamus.
# 2. Tetapkan
# Himpunan dalam bahasa pemrograman python adalah tipe data kolektif yang digunakan untuk menyimpan banyak nilai dalam satu variabel dengan berikut ini
# kondisi:
# • nilai anggota yang disimpan harus unik (bukan duplikat)
# • Nilai member yang sudah dimasukkan tidak dapat diubah lagi
# • set bersifat unordered alias tidak berurutan yang artinya tidak bisa diakses berdasarkan indeks.
# untuk lebih memahami 3 poin diatas, langsung saja kita lakukan prakteknya

# %%
# use curly brackets to declare sets.
student_set = {'Huda', 'Lendis', 'Wahid', 'Basith'}
print(student_set)

# sets with different data types
fruit_set = {'mango', 'apple'}
print(fruit_set)

# mix set
set_mix = {('man','animal'), 5, True, ('A','B')}
print(set_mix)

# %% [markdown]
# Outputs:
# {'Wahid', 'Lendis', 'Basith', 'Huda'}
# {'apel', 'mangga'}
# {True, 5, ('A', 'B'), 'hewan', 'manusia'}
# a. Unordered (Set)
# The data set type is unordered. That means, we can't use index
# to access the values in the set. Even if we force, we will only get an
# error:
# my_set = {'a'} print(my_set[0])
# Error message:
# in the set. Even if we force, we will only get an
#
# Traceback (most recent call last):
# File "<stdin>", line 1, in <module>
# TypeError: 'set' object is note subscriptable
#
# We can also look at the program code that we created earlier:
# student_set = { 'Huda', 'Lendis', 'Wahid', 'Basith'} print(student_set)
# Outputs:
# {'Wahid', 'Lendis', 'Basith', 'Huda'}
# Where above we define the 4 members of the set in order: Huda, Lendis, Wahid, and Basith. However, after we print, we get a different order.
# b. Unchangeable (Set)
# Sets are unchangeable, which means that the values we have entered into the set cannot be changed again.
# However, we can still add and remove members to the set. And, because sets are unchangeable, they can only accept members of data types that are also immutable.

# %% [markdown]
# Outputs:
# {'Wahid', 'Lendis', 'Basith', 'Huda'}
# {'apel', 'mangga'}
# {True, 5, ('A', 'B'), 'hewan', 'manusia'}
#
# A. Tidak Terurut (Set)
# Tipe kumpulan data tidak berurutan. Artinya, kita tidak bisa menggunakan index
# untuk mengakses nilai-nilai di set. Kalaupun kita memaksa, kita hanya akan mendapat
# Error:
#
# my_set = {'a'}
# print(my_set[0])
#
# Error message:
#
# Traceback (most recent call last):
# File "<stdin>", line 1, in <module>
# TypeError: 'set' object is note subscriptable
#
# Kita juga bisa melihat kode program yang telah kita buat tadi:
#
# student_set = { 'Huda', 'Lendis', 'Wahid', 'Basith'}
# print(student_set)
#
# Outputs:
# {'Wahid', 'Lendis', 'Basith', 'Huda'}
#
# Dimana diatas kita definisikan 4 anggota himpunan secara berurutan: Huda, Lendis, Wahid, dan Basith. Namun setelah kami cetak, kami mendapat pesanan yang berbeda.
#
# B. Tidak dapat diubah (Set)
# Himpunan tidak dapat diubah, artinya nilai yang telah kita masukkan ke dalam himpunan tidak dapat diubah lagi.
# Namun, kami masih dapat menambah dan menghapus anggota ke kumpulan tersebut. Dan, karena kumpulan tidak dapat diubah, kumpulan hanya dapat menerima anggota tipe data yang juga tidak dapat diubah.

# %%
# Consider the following example:
# set members must be of immutable data type
set_fruit = { 'mango', 'lemon', 'avocado', True, 1, 2, 3 }
# we can make tuple a member
# because it is immutable 
keyboard_= {
(1, 2, 3), 
(4, 5, 6),
(7, 8, 9),
(0)
}

# %% [markdown]
# Perhatikan contoh berikut:
# # anggota kumpulan harus bertipe data yang tidak dapat diubah
# set_fruit = { 'mangga', 'lemon', 'alpukat', Benar, 1, 2, 3 }
# # kita dapat menjadikan Tuple sebagai anggota
# # karena tidak dapat diubah
# papan ketik_= {
# (1, 2, 3),
# (4, 5, 6),
# (7, 8, 9),
# (0)
# }
# Namun kami tidak dapat menyertakan list sebagai anggota karena list dapat diubah. Perhatikan contoh berikut:
# x = himpunan{ 35, 100, ['a', 'b'] }
# Pesan eror:
# Unaul
# Traceback (panggilan terakhir terakhir):
# File "<stdin>", baris 1, di <modul>
# TypeError: jenis yang tidak dapat di-hash: 'daftar'
#
# C. Tidak ada Nilai duplikat (Set)
# Juga diatur dalam python tidak dapat menerima nilai duplikat. Jika kita memasukkan suatu nilai yang sudah ada pada suatu himpunan, maka nilai tersebut hanya akan muncul atau dimasukkan satu kali saja. Perhatikan contoh berikut:
#
# kata_unik = {
# 'pagi', 'ini', 'adalah', 'pagi', 'yang mana',
# 'sangat terang'}
#
# cetak(kata_unik)
#
# Maka kata “pagi” hanya akan dimasukkan satu kali:
# {'itu', 'sangat', 'ini', 'pagi', 'cerah', 'adalah'}

# %% [markdown]
# Consider the following example:
# # set members must be of immutable data type
# set_fruit = { 'mango', 'lemon', 'avocado', True, 1, 2, 3 }
# # we can make tuple a member
# # because it is immutable
# keyboard_= {
# (1, 2, 3),
# (4, 5, 6),
# (7, 8, 9),
# (0)
# }
# But we can't include list as a member because list is mutable. Consider the following example:
# x = set{ 35, 100, ['a', 'b'] }
# Error message:
# Unaaul
# Traceback (most recent call last):
# File "<stdin>", line 1, in <module>
# TypeError: unhashable type: 'list'
#
# c. No duplicate Values (Set)
# Also set in python can't accept duplicate values. If we enter a value that already exists in a set, then that value will only appear or be entered once. Consider the following example:
#
# unique_word = {
# 'morning', 'this', 'is', 'morning', 'which',
# 'very', 'bright'}
#
# print(unique_word)
#
# Then the word "morning" will only be entered once:
# {'that', 'very', 'this', 'morning', 'sunny', 'is'}

# %% [markdown]
# D. Tambahkan/Perbarui Elemen Kumpulan
# Seperti yang telah kami sebutkan di atas bahwa meskipun nilai yang ditetapkan tidak dapat diubah, namun tetap dapat ditambah dan dihapus. Kita dapat menambahkan anggota baru ke set dengan fungsi add() dan update(). Perhatikan contoh berikut:
#
# alfabet_set = {'a', 'b', 'c'}
# cetak (kumpulan abjad)
# # tambahkan satu per satu
# set_abjad.tambahkan('d')
# set_abjad.tambahkan('e')
# # tambahkan lebih dari satu anggota sekaligus
# set_abjad.update({ 'f', 'g' })
# # juga bisa menggunakan daftar
# set_abjad.update(['h', 'i'])
# cetak (kumpulan abjad)
#
# Keluaran:
# {'a', 'c', 'b'}
# {'d', '', 'e', ​​'b', 'g', 'h', 'f', 'c'}
#
# E. Hapus/hapus Elemen Set
# Untuk menghapus anggota dari suatu himpunan, ada 4 fungsi yang bisa kita gunakan:
# ⚫ hapus(nilai) Untuk menghapus nilai yang dicari. Jika nilai yang dicari tidak ada maka akan terjadi error.
# ⚫ membuang(nilai) Untuk menghapus nilai yang dicari. Jika nilai yang dicari tidak ada maka tidak akan terjadi error.
# ⚫ pop() Mengambil dan menghapus nilai di sebelah kiri.
# ⚫clear() Menghapus semua anggota.
#
# Contoh :
# set = {'virtual', 'berbudi luhur', 100, ('a', 'b'), false, True} print (set)

# %% [markdown]
# d. Add/Update Set Elements
# As we mentioned above that even though the set value cannot be changed, it can still be added and deleted. We can add new members to the set with the add() and update() functions. Consider the following example:
#
# alphabet_set = {'a', 'b', 'c'}
# print(alphabetical set)
# # add one by one
# set_abjad.add('d')
# set_abjad.add('e')
# # add more than one member at a time
# set_abjad.update({ 'f', 'g' })
# # can also use lists
# set_abjad.update(['h', 'i'])
# print(alphabetical set)
#
# Outputs:
# {'a', 'c', 'b'}
# {'d', '', 'e', 'b', 'g', 'h', 'f', 'c'}
#
# e. Delete/remove Set Elements
# To remove members from a set, there are 4 functions that we can use:
# ⚫ remove(value) To remove the searched value. If the searched value does not exist, then an error will occur.
# ⚫ discard(value) To delete the searched value. If the searched value does not exist, there will be no error.
# ⚫ pop() Retrieves and removes the value on the left.
# ⚫clear() Removes all members.
#
# Example :
# set = {'virtual', 'virtuous', 100, ('a', 'b'), false, True} print (set)

# %% [markdown]
# # akan error jika nilai 100 tidak ada di set
# set.remove(100)
# print(set)
# # tidak akan error jika ('a', 'b') tidak ada dalam set
# set.discard (('a', 'b'))
# print(set)
# # hapus nilai di sebelah kiri Hapusnilai = set.pop()
# print('Removed value =', valueDeleted)
# print(set)
# # hapus semua nilai set.clear() print(set)
# Outputs:
# {False, True, 100, 'maya', 'budi', ('a', 'b')}
# {False, True, 'maya', 'budi'}
# {False, True, 'maya', 'budi'}
# nilaiYangDihapus = False
# {True, 'maya', 'budi'}
# set()
#
# F. Functions (Sets)
# Berikut ringkasan fungsi bawaan tipe data set yang bisa kita gunakan:
#
# Function
# 1. add()
# 2. clear()
#
# Kegunaan
# 1. Menambahkan satu anggota ke set
# 2. Menghapus seluruh set

# %% [markdown]
# # will error if the value 100 is not in the set
# set.remove(100)
# print(set)
# # will not error if ('a', 'b') is not in the set
# set.discard (('a', 'b'))
# print(set)
# # remove the value on the left Removedvalue = set.pop()
# print('Removed value =', valueDeleted)
# print(set)
# # delete all values set.clear() print(set)
# Outputs:
# {False, True, 100, 'maya', 'budi', ('a', 'b')}
# {False, True, 'maya', 'budi'}
# {False, True, 'maya', 'budi'}
# nilaiYangDihapus = False
# {True, 'maya', 'budi'}
# set()
#
# f. Functions (Sets)
# The following is a summary of the built-in functions of the data set type that we can use:
#
# Function
# add()
# clear()
#
# Utility
# Adding one member to the set
# Deleting the entire set

# %% [markdown]
# copy() Membuat salinan satu set menjadi set baru
# perbedaan() Melakukan operasi perbedaan antara dua set
# Difference_update() Menghapus anggota himpunan lain yang ada di himpunan saat ini
# membuang() Menghapus satu anggota dari himpunan
# persimpangan() Melakukan operasi irisan antara dua set
# Intersection_update() Memperbarui anggota yang merupakan potongan dari dua set
# isdisjoint() Mengembalikan nilai True jika dua set tidak memiliki irisan
# issusbset() Mengembalikan nilai True jika himpunan lain memiliki anggota dari himpunan saat ini
# issuperset() Mengembalikan nilai True jika himpunan saat ini memiliki anggota dari himpunan lain
# pop() Menghapus dan mengembalikan nilai yang dihapus dari suatu set
# hapus() Menghapus nilai dari suatu set

# %% [markdown]
# copy() Make a copy of one set into a new set
# difference() Performing the difference operation between two sets
# difference_update() Delete other set members that are in the current set
# discard() Removing one member from the set
# intersection() Performing a slice operation between two sets
# intersection_update() Updating the member that is the slice of two sets
# isdisjoint() Returns value True if two sets have no slice
# issusbset() Returns value True if another set has members from the current set
# issuperset() Returns value True if the current set has members from another set
# pop() Removes and returns deleted values from a set
# remove() Removing a value from a set

# %% [markdown]
# perbedaan simetris() Melakukan operasi komplemen antara dua himpunan
# perbedaan simetris_update() Memperbarui kumpulan hasil pelengkap
# union() Melakukan operasi gabungan dua set atau lebih
# update() Memperbarui set dengan menambahkan nilai tertentu

# %% [markdown]
# symmetric difference() Perform the complement operation between two sets
# symmetric difference_update() Updating the set of complement results
# union() Performs a joint operation of two or more sets
# update() Updating the set by adding a specified value

# %% [markdown]
# 3. Kamus
# Kamus merupakan tipe data pada python yang berfungsi untuk menyimpan kumpulan data/nilai dengan pendekatan “key-value”. Kamus itu sendiri memiliki dua komponen inti: Yang pertama adalah kuncinya, yaitu nama atribut suatu item dalam kamus. Yang kedua adalah nilai, yaitu nilai yang disimpan dalam suatu atribut.
#
# Item kamus mempunyai 3 sifat yaitu:
# Tidak berurutan - tidak berurutan
# Dapat diubah - dapat diubah
# Unik - alias tidak dapat menerima dua kunci yang sama
#
# Unordered artinya tidak berurutan, jadi key/atribut yang kita definisikan terlebih dahulu, bukan berarti justru akan menjadi yang “pertama” dibandingkan dengan key yang lain. Selain itu, tidak berurutan berarti tidak dapat diakses menggunakan indeks (bilangan bulat) seperti halnya daftar.
#
# Changeableartinya kita dapat mengubah nilai yang telah kita masukkan ke dalam kamus. Ini berbeda dengan tipe data set dan tuple, yang keduanya bersifat immutable atau tidak dapat diubah.
#
# Dan yang terakhir Unique, kamus tidak boleh memiliki lebih dari satu kunci yang sama karena bersifat unik. Jadi jika dua kunci sama, kunci yang terakhir ditentukan akan menimpa nilai kunci yang ditentukan sebelumnya.
#
# A. Buat Elemen Kamus
# Selanjutnya cara membuat kamus dengan python. Untuk membuatnya ada 2 cara :
# • Yang pertama dengan kurung kurawal {}.
# • Dan yang kedua bisa menggunakan fungsi atau konstruktor dict().
# Perhatikan contoh berikut:
# # Langkah pertama
# buku = {
# }
# "judul": "Daun Musim Gugur Tak Pernah Membenci Angin", "Penulis": "Tere Liye"
#
# # cara kedua
# buku = dikte(
# title="Daun Musim Gugur Tak Pernah Benci Angin", author="Tere Liye"
# )

# %% [markdown]
# 3. Dictionary
# Dictionary is a data type in python that serves to store a collection of data / values with a "key-value" approach. The dictionary itself has two core components: The first is the key, it is the attribute name of an item in the dictionary. The second is value, it is the value stored in an attribute.
#
# Dictionary items have 3 properties, namely:
# Unordered - not in order
# Changeable - can be changed
# Unique - alias cannot accept the same two keys
#
# Unorderedmeaning it is not sequential, so the key/attribute that we define first, does not mean it will actually be the "first" compared to the other keys. Also, unordered means that it cannot be accessed using an index (integer) as is the case with a list.
#
# Changeablemeaning we can we change the value that we have entered into a dictionary. This is different from the set and tuple data types, both of which are immutable or cannot be changed.
#
# And lastly Unique, a dictionary cannot have more than one same key because it is unique. So if two keys are the same, the last defined key will overwrite the value of the earlier defined key.
#
# a. Create Dictionary Elements
# Next is how to create a dictionary in python. To make it, there are 2 ways:
# • The first with curly braces {}.
# • And the second one can use the dict() function or constructor.
# Consider the following example:
# # first step
# book = {
# }
# "title": "Fall Leaves Never Hate The Wind", "Writer": "Tere Liye"
#
# # second way
# book = dict(
# title="Fall Leaves Never Hate The Wind", author="Tere Liye"
# )

# %% [markdown]
# B. Tambahkan/Perbarui Elemen Dict
# Untuk menambahkan kunci dan item baru, caranya seperti mengedit item. Jadi: Jika key yang kita tentukan sudah ada, maka sistem akan mengganti item lama dengan yang baru alias mengeditnya. Namun jika kunci yang kita definisikan tidak ada, sistem akan menambahkannya sebagai item baru.
#
# Contoh:
# murid = {
# 'nama': 'Lendis Fabri',
# 'asal': 'Indonesia',
# }
#
# # keluaran Tidak ada
# print('Hobi:', pelajar.dapatkan('hobi'))
# # tambahkan data
# pelajar['hobi'] = 'Memancing'
# #cetak ulang
# print('Hobi {} adalah {}'.format(
# siswa.dapatkan('nama'),
# pelajar.mendapatkan('hobi')
# ))
#
# Keluaran:
# Hobi: Tidak ada
# Hobi dari Lendis Fabri adalah Memancing
#
# C. Hapus Elemen Dict
# Ada dua cara untuk menghapus item:
# ⚫ Menggunakan pernyataan del.
# ⚫ Atau gunakan fungsi kamus.pop()
#
# Perhatikan contoh berikut:
# murid = {
# 'nama': 'Wahid Abdullah',
# 'usia': 18,

# %% [markdown]
# b. Add/Update Dict Elements
# To add new keys and items, the method is like editing items. So: If the key we defined already exists, the system will replace the old item with the new one, aka edit it. But if the key we defined doesn't exist, the system will add it as a new item.
#
# Example:
# student = {
# 'name': 'Lendis Fabri',
# 'origin': 'Indonesia',
# }
#
# # output None
# print('Hobby:', student.get('hobby'))
# # add data
# student['hobby'] = 'Fishing'
# # reprint
# print('Hobby of {} is {}'.format(
# student.get('name'),
# student.get('hobby')
# ))
#
# Outputs:
# Hobi: None
# Hobi dari Lendis Fabri adalah Memancing
#
# c. Delete Dict Elements
# There are two ways to delete an item:
# ⚫ Using the del  statement.
# ⚫ Or use the dictionary.pop() function
#
# Consider the following example:
# student = {
# 'name': 'Wahid Abdullah',
# 'age': 18,

# %% [markdown]
# symmetric_difference():
# - Melakukan operasi komplementer antara dua set.
# - Menghasilkan set yang berisi elemen-elemen yang hanya ada di salah satu dari dua set (bukan di keduanya).
# Contoh: A.symmetric_difference(B) menghasilkan set dengan elemen-elemen unik dari A dan B.
#
# symmetric_difference_update():
# - Memperbarui set dengan hasil operasi komplementer.
# - Menggabungkan elemen-elemen yang hanya ada di salah satu dari dua set ke dalam set yang sedang diperbarui.
# Contoh: A.symmetric_difference_update(B) mengubah set A dengan elemen-elemen unik dari A dan B.
#
# union():
# - Melakukan operasi gabungan (union) dari dua atau lebih set.
# - Menghasilkan set yang berisi semua elemen yang ada di set-set yang digabungkan.
# Contoh: A.union(B) menghasilkan set dengan semua elemen dari A dan B.
#
# update():
# - Memperbarui set dengan menambahkan nilai tertentu.
# - Menambahkan elemen-elemen baru ke dalam set yang sedang diperbarui.

# %% [markdown]
# 3. Dictionary
#         Dictionary is a data type in python that serves to store a collection of data / values with a "key-value" approach. The dictionary itself has two core components: The first is the key, it is the attribute name of an otem in the dictionary. the second is value, it is the value stored in an attribute.
#
#             Dictionary items have 3 properties, namely:
#         - Unordered - not in order
#         - Changeable - can be changed
#         - Unique - alias cannot accept the same two keys
#
#     Unoredered meaning it is not sequential, so the key/attribute that we define first
